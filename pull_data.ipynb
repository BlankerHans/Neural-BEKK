# %% [markdown]
# # Generate Log Returns from Yahoo Finance Price Data

# %%
import yfinance as yf
import os
import pandas as pd

# %%
tickers = "^GSPC BTC-USD GC=F"  # S&P 500 index, Bitcoin, Gold
data = yf.download(tickers, period="max")
close = data["Close"].copy()
# Out:
# /var/folders/94/8_7g7dqx72760sk83dk1klgc0000gn/T/ipykernel_4188/809094188.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="max")
# [*********************100%***********************]  3 of 3 completed

# %%
logret = np.log(close).diff() # log(P_t) - log(P_{t-1})) = log(P_t / P_{t-1})

# Aufräumen: erste Zeile NaN durch diff, ggf. weitere NaNs durch Datenlücken
logret = logret.dropna()

# %%
# save logret to csv
logret.to_csv("log_returns.csv")
